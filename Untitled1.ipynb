# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat      Lng  Max Temp  Humidity  \
# 0        0       puerto ayora  -0.7393 -90.3518     24.19        95
# 1        1          kani keli -12.9536  45.1033     28.59        78
# 2        2  port-aux-francais -49.3500  70.2167      2.58        88
# 3        3          vorgashor  67.5833  63.9500     27.60        44
# 4        4          jamestown  42.0970 -79.2353     21.77        94
#
#    Cloudiness  Wind Speed Country        Date
# 0          18        1.79      EC  1691131656
# 1          31        8.50      YT  1691131657
# 2          70       14.48      TF  1691131657
# 3           0        2.26      RU  1691131657
# 4           0        1.54      US  1691131618

# %%
# %%capture --no-display
map_plot = city_data_df.hvplot.points(
    "Lng", 
    "Lat", 
    geo=True,
    tiles="OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 0.5,
    color = "City"
)
# Display the map plot
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %%
#%%capture --no-display
radius = 3000
latitude = -31.9477365
longitude = 115.8387213036199
base_url = "https://api.geoapify.com/v2/places"

params={
    "categories": "accommodation.hotel",
    "apiKey":geoapify_key,
    "format":"json"
     }
params["filter"] = f"circle:{longitude},{latitude},{radius}"
params["bias"] = f"proximity:{longitude},{latitude}"
#url = "https://api.geoapify.com/v2/places?PARAMS"
response=requests.get(base_url,params=params)
name_address = response.json()
# Configure the map plot
#map_plot = city_data_df.hvplot(x='Lng', y='Lat', geo=True, hover_cols=['City'], title='City Map')

# Display the map
#map_plot.show()
name_address
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'name': 'Sage Hotel West Perth',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'Western Australia',
#     'county': 'City of Perth',
#     'city': 'Perth',
#     'postcode': '6005',
#     'suburb': 'West Perth',
#     'street': 'Hay Street',
#     'housenumber': '1309',
#     'lon': 115.8387172,
#     'lat': -31.947806,
#     'state_code': 'WA',
#     'formatted': 'Sage Hotel West Perth, 1309 Hay Street, West Perth WA 6005, Australia',
#     'address_line1': 'Sage Hotel West Perth',
#     'address_line2': '1309 Hay Street, West Perth WA 6005, Australia',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'internet_access',
#      'internet_access.free'],
#     'details': ['details',
#      'details.accommodation',
#      'details.contact',
#      'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
# ...

# %%
url = "https://api.geoapify.com/v1/geocode/search?text='kapaa'&bias=proximity:-159.3190,22.0752&format=json&apiKey=8ee9045760f44e67a3fcd8135f0d536b"
url    
https://api.geoapify.com/v1/geocode/search?&format=json&apiKey=8ee9045760f44e67a3fcd8135f0d536b
# Out:
# 'https://api.geoapify.com/v1/geocode/search?text=Hannoverstr.&bias=proximity:7.0652029,52.4309185&format=json&apiKey={geoapify_key}'
